# %% [markdown]
# # Importing Libraries

# %%
import numpy as np   # mathematical Calculation
import pandas as pd  # File/DataFrame handling

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# # Reading Dataset

# %%
Dataset = pd.read_csv("/content/drive/MyDrive/Project/DataSet/Features_Combined.csv")

# %%
Dataset["labels"].unique()
# Out:
# array(['calm', 'sad', 'happy', 'neutral', 'angry', 'disgust', 'fear',
#        'surprise'], dtype=object)

# %%
Dataset.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000056  0.000195  0.000281  0.000119  0.000119  0.003826  0.215466
# 1  0.000203  0.000322  0.000439  0.000271  0.000265  0.003977  0.215628
# 2  0.000012  0.000048  0.000069  0.000038  0.000026  0.000213  0.008568
# 3  0.000052  0.000118  0.000180  0.000401  0.000892  0.033079  0.149234
# 4  0.000480  0.000538  0.000612  0.000840  0.001356  0.033393  0.147666
#
#           7         8         9  ...        139       140       141       142  \
# 0  0.779309  1.186640  0.456590  ... -11.354362 -7.726419  1.593689 -9.145521
# 1  0.776650  1.184454  0.458336  ... -10.847643 -6.654379 -1.465691 -6.797494
# 2  0.090721  0.256162  0.167146  ... -13.176809 -3.879907 -0.284960 -9.416859
# 3  0.258785  0.233824  0.028744  ...  -3.513651 -0.170925 -5.336728  1.003468
# 4  0.261492  0.236123  0.028882  ...  -3.040922 -2.138857 -3.132770 -1.381131
#
#         143       144       145       146       147  labels
# 0 -0.212657 -6.929526 -4.322876 -4.710403 -8.351056    calm
# 1 -3.094689 -6.291496 -4.512487 -4.711416 -8.531783    calm
# 2  0.278055 -8.788507 -4.630785 -7.198601 -8.594221    calm
# 3 -3.568468 -5.821103 -3.620392 -4.771007 -3.185519     sad
# 4 -2.552100 -4.274347 -2.680576 -4.152612 -3.639899     sad
#
# [5 rows x 149 columns]

# %% [markdown]
# # Replacing Emotions by values

# %%
Dataset = Dataset.replace("calm", 0)
Dataset = Dataset.replace("sad", 1)
Dataset = Dataset.replace("happy", 2)
Dataset = Dataset.replace("neutral", 3)
Dataset = Dataset.replace("angry", 4)
Dataset = Dataset.replace("disgust", 5)
Dataset = Dataset.replace("fear", 6)
Dataset = Dataset.replace("surprise", 7)

# %%
Dataset.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000056  0.000195  0.000281  0.000119  0.000119  0.003826  0.215466
# 1  0.000203  0.000322  0.000439  0.000271  0.000265  0.003977  0.215628
# 2  0.000012  0.000048  0.000069  0.000038  0.000026  0.000213  0.008568
# 3  0.000052  0.000118  0.000180  0.000401  0.000892  0.033079  0.149234
# 4  0.000480  0.000538  0.000612  0.000840  0.001356  0.033393  0.147666
#
#           7         8         9  ...        139       140       141       142  \
# 0  0.779309  1.186640  0.456590  ... -11.354362 -7.726419  1.593689 -9.145521
# 1  0.776650  1.184454  0.458336  ... -10.847643 -6.654379 -1.465691 -6.797494
# 2  0.090721  0.256162  0.167146  ... -13.176809 -3.879907 -0.284960 -9.416859
# 3  0.258785  0.233824  0.028744  ...  -3.513651 -0.170925 -5.336728  1.003468
# 4  0.261492  0.236123  0.028882  ...  -3.040922 -2.138857 -3.132770 -1.381131
#
#         143       144       145       146       147  labels
# 0 -0.212657 -6.929526 -4.322876 -4.710403 -8.351056       0
# 1 -3.094689 -6.291496 -4.512487 -4.711416 -8.531783       0
# 2  0.278055 -8.788507 -4.630785 -7.198601 -8.594221       0
# 3 -3.568468 -5.821103 -3.620392 -4.771007 -3.185519       1
# 4 -2.552100 -4.274347 -2.680576 -4.152612 -3.639899       1
#
# [5 rows x 149 columns]

# %% [markdown]
# # Extracting Features and Labels

# %%
# Labels
labels = np.array(Dataset['labels'])

# %%
# Features
features= Dataset.drop('labels', axis = 1)
features = np.array(features)

# %% [markdown]
# # Train-Test Split

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (3456, 148)
# Training Labels Shape: (3456,)
# Testing Features Shape: (1152, 148)
# Testing Labels Shape: (1152,)

# %% [markdown]
# # Classification ML Algorithms

# %% [markdown]
# ### Note :- Logistic Regression cant be used as we have more than 2 Classes
# ###         Logistic Regression works with only 2 classes

# %% [markdown]
# ## 1. Naive Bayes

# %%
# Importing Model
from sklearn.naive_bayes import GaussianNB

# %%
# Initializing Model
Naive_Bayes = GaussianNB()

# %%
# Training Model
Naive_Bayes.fit(train_features, train_labels)
# Out:
# GaussianNB()

# %%
# Performing Predictions
y_pred = Naive_Bayes.predict(test_features)

# %%
# Calculating Model Performance

class_names = ['calm', 'sad', 'happy', 'neutral', 'angry', 'disgust', 'fear', 'surprise']

print (classification_report(test_labels, y_pred, target_names = class_names))
# Out:
#               precision    recall  f1-score   support
#
#         calm       0.25      0.90      0.39       136
#          sad       0.15      0.14      0.15       147
#        happy       0.26      0.14      0.18       140
#      neutral       0.17      0.22      0.19       145
#        angry       0.70      0.33      0.45       146
#      disgust       0.20      0.07      0.11       148
#         fear       0.30      0.09      0.13       141
#     surprise       0.24      0.15      0.19       149
#
#     accuracy                           0.25      1152
#    macro avg       0.28      0.26      0.22      1152
# weighted avg       0.28      0.25      0.22      1152

# %% [markdown]
# ## 2. Random Forest

# %%
# Importing Model
from sklearn.ensemble import RandomForestClassifier

# %%
# Initializing Model
rf = RandomForestClassifier(n_estimators = 1000, random_state = 42)

# %%
# Trainig Model
rf.fit(train_features, train_labels)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=42)

# %%
# Performing Predictions
y_pred = rf.predict(test_features)

# %%
# Calculating Model Performance

class_names = ['calm', 'sad', 'happy', 'neutral', 'angry', 'disgust', 'fear', 'surprise']

print (classification_report(test_labels, y_pred, target_names = class_names))
# Out:
#               precision    recall  f1-score   support
#
#         calm       0.71      0.93      0.80       136
#          sad       0.78      0.63      0.70       147
#        happy       0.82      0.70      0.75       140
#      neutral       0.78      0.92      0.84       145
#        angry       0.91      0.75      0.82       146
#      disgust       0.68      0.71      0.69       148
#         fear       0.78      0.67      0.72       141
#     surprise       0.70      0.78      0.74       149
#
#     accuracy                           0.76      1152
#    macro avg       0.77      0.76      0.76      1152
# weighted avg       0.77      0.76      0.76      1152

# %% [markdown]
# ## 3. Support Vector Machine {SVM}

# %%
# Importing Model
from sklearn.svm import SVC

# %%
# Initializing Model
svm = SVC(kernel = 'linear', C=0.025, random_state=10)

# %%
# Trainig Model
svm.fit(train_features, train_labels)
# Out:
# SVC(C=0.025, kernel='linear', random_state=10)

# %%
# Performing Predictions
y_pred = svm.predict(test_features)

# %%
# Calculating Model Performance

class_names = ['calm', 'sad', 'happy', 'neutral', 'angry', 'disgust', 'fear', 'surprise']

print (classification_report(test_labels, y_pred, target_names = class_names))
# Out:
#               precision    recall  f1-score   support
#
#         calm       0.45      0.62      0.52       136
#          sad       0.40      0.43      0.41       147
#        happy       0.40      0.34      0.37       140
#      neutral       0.49      0.48      0.48       145
#        angry       0.69      0.60      0.64       146
#      disgust       0.32      0.39      0.35       148
#         fear       0.47      0.43      0.45       141
#     surprise       0.55      0.40      0.47       149
#
#     accuracy                           0.46      1152
#    macro avg       0.47      0.46      0.46      1152
# weighted avg       0.47      0.46      0.46      1152

# %% [markdown]
# ## 4. K-Nearest Neighbour {KNN}

# %%
# Importing Model
from sklearn.neighbors import KNeighborsClassifier

# %%
# Initializing Model
knn = KNeighborsClassifier(n_neighbors=15)

# %%
# Training Model
knn.fit(train_features, train_labels)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
# Performing Predictions
y_pred = knn.predict(test_features)

# %%
# Calculating Model Performance

class_names = ['calm', 'sad', 'happy', 'neutral', 'angry', 'disgust', 'fear', 'surprise']

print (classification_report(test_labels, y_pred, target_names = class_names))
# Out:
#               precision    recall  f1-score   support
#
#         calm       0.35      0.51      0.41       136
#          sad       0.33      0.26      0.29       147
#        happy       0.33      0.37      0.35       140
#      neutral       0.30      0.48      0.37       145
#        angry       0.57      0.53      0.55       146
#      disgust       0.33      0.26      0.29       148
#         fear       0.38      0.28      0.33       141
#     surprise       0.38      0.24      0.29       149
#
#     accuracy                           0.36      1152
#    macro avg       0.37      0.37      0.36      1152
# weighted avg       0.37      0.36      0.36      1152
